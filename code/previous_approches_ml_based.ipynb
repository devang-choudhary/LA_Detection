# %%
import json
import adaboost
import decisiontree
import knn_content
import logistic_regression_content
import svm_content

# %%
json_path = 'projects_list.json'
with open(json_path, 'r') as f:
    data = json.load(f)

# %%
for project,url in data.items():
    print(f'project: {project}')
    print(f'ada boost:')
    adaboost.adaboost(project)
    print(f'decision tree:')
    decisiontree.decision_tree(project)
    print(f'knn:')
    knn_content.knn(project)
    print(f'logistic regression:')
    logistic_regression_content.lr(project)
    print(f'svm:')
    svm_content.svm(project)
# Out:
# project: buildship
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.44      0.12      0.18       599
#       not_LA       0.00      0.00      0.00        68
#           is       0.61      0.91      0.73      1042
#          set       0.97      0.95      0.96       329
#
#     accuracy                           0.66      2038
#    macro avg       0.50      0.50      0.47      2038
# weighted avg       0.60      0.66      0.58      2038
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.38      0.37      0.37       599
#       not_LA       0.33      0.03      0.05        68
#           is       0.62      0.51      0.56      1042
#          set       0.98      0.98      0.98       329
#
#    micro avg       0.61      0.53      0.56      2038
#    macro avg       0.58      0.47      0.49      2038
# weighted avg       0.60      0.53      0.56      2038
#  samples avg       0.53      0.53      0.53      2038
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.46      0.61      0.53       599
#       not_LA       1.00      0.01      0.03        68
#           is       0.67      0.56      0.61      1042
#          set       0.94      0.94      0.94       329
#
#    micro avg       0.63      0.62      0.62      2038
#    macro avg       0.77      0.53      0.53      2038
# weighted avg       0.66      0.62      0.62      2038
#  samples avg       0.62      0.62      0.62      2038
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          get       0.47      0.47      0.47       599
#       not_LA       0.00      0.00      0.00        68
#           is       0.65      0.69      0.67      1042
#          set       0.96      0.94      0.95       329
#
#     accuracy                           0.64      2038
#    macro avg       0.52      0.52      0.52      2038
# weighted avg       0.62      0.64      0.63      2038
#
# svm:
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          get       0.48      0.26      0.34       599
#       not_LA       0.00      0.00      0.00        68
#           is       0.61      0.84      0.71      1042
#          set       1.00      0.83      0.91       329
#
#     accuracy                           0.64      2038
#    macro avg       0.52      0.48      0.49      2038
# weighted avg       0.61      0.64      0.61      2038
#
# project: eclips-collections
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.74      0.52      0.61       227
#       not_LA       0.54      0.78      0.64       177
#           is       0.89      0.93      0.91       508
#          set       0.11      0.02      0.04        43
#
#     accuracy                           0.76       955
#    macro avg       0.57      0.56      0.55       955
# weighted avg       0.75      0.76      0.75       955
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.89      0.84      0.87       227
#       not_LA       0.79      0.87      0.83       177
#           is       0.91      0.93      0.92       508
#          set       0.64      0.33      0.43        43
#
#    micro avg       0.87      0.87      0.87       955
#    macro avg       0.81      0.74      0.76       955
# weighted avg       0.87      0.87      0.87       955
#  samples avg       0.87      0.87      0.87       955
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.88      0.82      0.85       227
#       not_LA       0.53      0.49      0.51       177
#           is       0.81      0.79      0.80       508
#          set       0.65      0.26      0.37        43
#
#    micro avg       0.77      0.71      0.74       955
#    macro avg       0.72      0.59      0.63       955
# weighted avg       0.77      0.71      0.74       955
#  samples avg       0.71      0.71      0.71       955
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.75      0.82      0.79       227
#       not_LA       0.59      0.46      0.52       177
#           is       0.79      0.88      0.83       508
#          set       0.40      0.05      0.08        43
#
#     accuracy                           0.75       955
#    macro avg       0.63      0.55      0.55       955
# weighted avg       0.73      0.75      0.73       955
#
# svm:
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          get       0.79      0.85      0.82       227
#       not_LA       0.56      0.52      0.54       177
#           is       0.81      0.87      0.84       508
#          set       0.00      0.00      0.00        43
#
#     accuracy                           0.76       955
#    macro avg       0.54      0.56      0.55       955
# weighted avg       0.72      0.76      0.74       955
#
# project: hawkbit
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.45      0.44      0.45       171
#       not_LA       0.30      0.24      0.27        58
#           is       0.47      0.53      0.49       243
#          set       0.93      0.71      0.81        59
#
#     accuracy                           0.49       531
#    macro avg       0.54      0.48      0.50       531
# weighted avg       0.50      0.49      0.49       531
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.32      0.19      0.24       171
#       not_LA       0.80      0.69      0.74        58
#           is       0.53      0.53      0.53       243
#          set       0.91      0.85      0.88        59
#
#    micro avg       0.56      0.48      0.52       531
#    macro avg       0.64      0.57      0.60       531
# weighted avg       0.54      0.48      0.50       531
#  samples avg       0.48      0.48      0.48       531
# knn:
#               precision    recall  f1-score   support
#
#          get       0.42      0.44      0.43       171
#       not_LA       0.62      0.22      0.33        58
#           is       0.47      0.41      0.44       243
#          set       0.76      0.59      0.67        59
#
#    micro avg       0.48      0.42      0.45       531
#    macro avg       0.57      0.42      0.47       531
# weighted avg       0.50      0.42      0.45       531
#  samples avg       0.42      0.42      0.42       531
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.48      0.50      0.49       171
#       not_LA       0.59      0.22      0.32        58
#           is       0.52      0.62      0.57       243
#          set       0.93      0.68      0.78        59
#
#     accuracy                           0.54       531
#    macro avg       0.63      0.51      0.54       531
# weighted avg       0.56      0.54      0.54       531
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.53      0.10      0.17       171
#       not_LA       0.67      0.07      0.12        58
#           is       0.50      0.94      0.65       243
#          set       0.97      0.54      0.70        59
#
#     accuracy                           0.53       531
#    macro avg       0.67      0.41      0.41       531
# weighted avg       0.58      0.53      0.44       531
#
# project: jkube
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.48      0.51      0.49       237
#       not_LA       0.27      0.33      0.30        39
#           is       0.51      0.48      0.50       272
#          set       1.00      0.69      0.82        26
#
#     accuracy                           0.49       574
#    macro avg       0.56      0.50      0.53       574
# weighted avg       0.50      0.49      0.50       574
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.24      0.19      0.22       237
#       not_LA       0.78      0.72      0.75        39
#           is       0.39      0.39      0.39       272
#          set       0.95      0.81      0.88        26
#
#    micro avg       0.39      0.35      0.37       574
#    macro avg       0.59      0.53      0.56       574
# weighted avg       0.38      0.35      0.36       574
#  samples avg       0.35      0.35      0.35       574
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.42      0.46      0.44       237
#       not_LA       0.62      0.21      0.31        39
#           is       0.43      0.39      0.41       272
#          set       0.89      0.65      0.76        26
#
#    micro avg       0.45      0.42      0.43       574
#    macro avg       0.59      0.43      0.48       574
# weighted avg       0.46      0.42      0.43       574
#  samples avg       0.42      0.42      0.42       574
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.46      0.43      0.44       237
#       not_LA       0.50      0.05      0.09        39
#           is       0.48      0.57      0.52       272
#          set       0.95      0.73      0.83        26
#
#     accuracy                           0.49       574
#    macro avg       0.60      0.45      0.47       574
# weighted avg       0.49      0.49      0.47       574
#
# svm:
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          get       0.45      0.40      0.42       237
#       not_LA       0.00      0.00      0.00        39
#           is       0.46      0.60      0.52       272
#          set       1.00      0.46      0.63        26
#
#     accuracy                           0.47       574
#    macro avg       0.48      0.36      0.39       574
# weighted avg       0.45      0.47      0.45       574
#
# project: kura
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.47      0.42      0.45      1028
#       not_LA       0.69      0.57      0.62       544
#           is       0.61      0.68      0.64      2136
#          set       0.78      0.67      0.72       545
#
#     accuracy                           0.60      4253
#    macro avg       0.63      0.59      0.61      4253
# weighted avg       0.61      0.60      0.60      4253
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.36      0.35      0.36      1028
#       not_LA       0.87      0.84      0.86       544
#           is       0.66      0.62      0.64      2136
#          set       0.93      0.85      0.89       545
#
#    micro avg       0.64      0.61      0.63      4253
#    macro avg       0.70      0.67      0.68      4253
# weighted avg       0.65      0.61      0.63      4253
#  samples avg       0.61      0.61      0.61      4253
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.45      0.57      0.51      1028
#       not_LA       0.70      0.62      0.66       544
#           is       0.65      0.55      0.59      2136
#          set       0.91      0.78      0.84       545
#
#    micro avg       0.62      0.59      0.61      4253
#    macro avg       0.68      0.63      0.65      4253
# weighted avg       0.64      0.59      0.61      4253
#  samples avg       0.59      0.59      0.59      4253
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.48      0.37      0.42      1028
#       not_LA       0.78      0.74      0.76       544
#           is       0.65      0.75      0.70      2136
#          set       0.87      0.74      0.80       545
#
#     accuracy                           0.66      4253
#    macro avg       0.70      0.65      0.67      4253
# weighted avg       0.65      0.66      0.65      4253
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.67      0.00      0.00      1028
#       not_LA       0.83      0.64      0.72       544
#           is       0.60      0.96      0.74      2136
#          set       0.87      0.73      0.79       545
#
#     accuracy                           0.65      4253
#    macro avg       0.74      0.58      0.56      4253
# weighted avg       0.68      0.65      0.57      4253
#
# project: jifa
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.00      0.00      0.00        57
#       not_LA       0.50      0.25      0.33         4
#           is       0.49      0.98      0.65        62
#          set       1.00      0.69      0.82        13
#
#     accuracy                           0.52       136
#    macro avg       0.50      0.48      0.45       136
# weighted avg       0.33      0.52      0.39       136
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.20      0.16      0.18        57
#       not_LA       0.67      0.50      0.57         4
#           is       0.27      0.21      0.23        62
#          set       1.00      0.92      0.96        13
#
#    micro avg       0.33      0.26      0.30       136
#    macro avg       0.53      0.45      0.49       136
# weighted avg       0.32      0.26      0.29       136
#  samples avg       0.26      0.26      0.26       136
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          get       0.34      0.30      0.32        57
#       not_LA       0.67      0.50      0.57         4
#           is       0.40      0.44      0.42        62
#          set       1.00      0.92      0.96        13
#
#    micro avg       0.44      0.43      0.43       136
#    macro avg       0.60      0.54      0.57       136
# weighted avg       0.44      0.43      0.43       136
#  samples avg       0.43      0.43      0.43       136
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.37      0.33      0.35        57
#       not_LA       1.00      0.25      0.40         4
#           is       0.42      0.48      0.45        62
#          set       1.00      0.92      0.96        13
#
#     accuracy                           0.46       136
#    macro avg       0.70      0.50      0.54       136
# weighted avg       0.47      0.46      0.46       136
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.00      0.00      0.00        57
#       not_LA       1.00      0.25      0.40         4
#           is       0.50      1.00      0.66        62
#          set       1.00      0.62      0.76        13
#
#     accuracy                           0.52       136
#    macro avg       0.62      0.47      0.46       136
# weighted avg       0.35      0.52      0.39       136
#
# project: milo
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.49      0.86      0.63       936
#       not_LA       0.70      0.30      0.42        64
#           is       0.62      0.30      0.40      1199
#          set       0.95      0.76      0.84       237
#
#     accuracy                           0.56      2436
#    macro avg       0.69      0.55      0.57      2436
# weighted avg       0.61      0.56      0.53      2436
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.42      0.35      0.38       936
#       not_LA       0.84      0.66      0.74        64
#           is       0.55      0.57      0.56      1199
#          set       0.98      0.95      0.96       237
#
#    micro avg       0.56      0.52      0.54      2436
#    macro avg       0.70      0.63      0.66      2436
# weighted avg       0.55      0.52      0.53      2436
#  samples avg       0.52      0.52      0.52      2436
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.48      0.24      0.31       936
#       not_LA       0.69      0.52      0.59        64
#           is       0.56      0.77      0.65      1199
#          set       0.93      0.97      0.95       237
#
#    micro avg       0.58      0.58      0.58      2436
#    macro avg       0.66      0.62      0.63      2436
# weighted avg       0.57      0.58      0.55      2436
#  samples avg       0.58      0.58      0.58      2436
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.48      0.46      0.47       936
#       not_LA       0.77      0.56      0.65        64
#           is       0.57      0.59      0.58      1199
#          set       0.93      0.95      0.94       237
#
#     accuracy                           0.57      2436
#    macro avg       0.68      0.64      0.66      2436
# weighted avg       0.57      0.57      0.57      2436
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.46      0.10      0.17       936
#       not_LA       0.80      0.19      0.30        64
#           is       0.54      0.89      0.67      1199
#          set       0.94      0.93      0.93       237
#
#     accuracy                           0.57      2436
#    macro avg       0.68      0.53      0.52      2436
# weighted avg       0.56      0.57      0.50      2436
#
# project: openvsx
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.33      0.34      0.33       119
#       not_LA       0.68      0.69      0.68        78
#           is       0.67      0.66      0.67       268
#          set       0.98      0.93      0.96        60
#
#     accuracy                           0.62       525
#    macro avg       0.66      0.66      0.66       525
# weighted avg       0.63      0.62      0.63       525
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.27      0.23      0.25       119
#       not_LA       0.92      0.87      0.89        78
#           is       0.68      0.63      0.65       268
#          set       1.00      0.93      0.97        60
#
#    micro avg       0.67      0.61      0.64       525
#    macro avg       0.72      0.66      0.69       525
# weighted avg       0.66      0.61      0.63       525
#  samples avg       0.61      0.61      0.61       525
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.44      0.50      0.47       119
#       not_LA       0.79      0.68      0.73        78
#           is       0.69      0.63      0.66       268
#          set       0.95      0.95      0.95        60
#
#    micro avg       0.67      0.64      0.66       525
#    macro avg       0.72      0.69      0.70       525
# weighted avg       0.68      0.64      0.66       525
#  samples avg       0.64      0.64      0.64       525
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.35      0.23      0.28       119
#       not_LA       0.95      0.69      0.80        78
#           is       0.65      0.81      0.72       268
#          set       0.98      0.97      0.97        60
#
#     accuracy                           0.68       525
#    macro avg       0.73      0.67      0.69       525
# weighted avg       0.66      0.68      0.66       525
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.32      0.06      0.10       119
#       not_LA       0.96      0.60      0.74        78
#           is       0.63      0.94      0.75       268
#          set       1.00      0.87      0.93        60
#
#     accuracy                           0.68       525
#    macro avg       0.73      0.62      0.63       525
# weighted avg       0.65      0.68      0.62       525
#
# project: steady
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.49      0.59      0.53       599
#       not_LA       0.72      0.52      0.61       208
#           is       0.67      0.66      0.66      1180
#          set       0.92      0.79      0.85       333
#
#     accuracy                           0.65      2320
#    macro avg       0.70      0.64      0.66      2320
# weighted avg       0.66      0.65      0.65      2320
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.27      0.13      0.17       599
#       not_LA       0.90      0.64      0.75       208
#           is       0.63      0.75      0.68      1180
#          set       0.95      0.98      0.97       333
#
#    micro avg       0.66      0.61      0.63      2320
#    macro avg       0.69      0.62      0.64      2320
# weighted avg       0.61      0.61      0.60      2320
#  samples avg       0.61      0.61      0.61      2320
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.42      0.30      0.35       599
#       not_LA       0.71      0.44      0.54       208
#           is       0.62      0.70      0.66      1180
#          set       0.90      0.94      0.92       333
#
#    micro avg       0.63      0.61      0.62      2320
#    macro avg       0.66      0.60      0.62      2320
# weighted avg       0.62      0.61      0.61      2320
#  samples avg       0.61      0.61      0.61      2320
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.48      0.52      0.50       599
#       not_LA       0.61      0.37      0.46       208
#           is       0.66      0.67      0.66      1180
#          set       0.92      0.92      0.92       333
#
#     accuracy                           0.64      2320
#    macro avg       0.67      0.62      0.63      2320
# weighted avg       0.64      0.64      0.64      2320
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.22      0.00      0.01       599
#       not_LA       0.74      0.08      0.15       208
#           is       0.58      0.99      0.73      1180
#          set       0.97      0.84      0.90       333
#
#     accuracy                           0.63      2320
#    macro avg       0.63      0.48      0.45      2320
# weighted avg       0.56      0.63      0.52      2320
#
# project: xtext
# ada boost:
#               precision    recall  f1-score   support
#
#          get       0.44      0.08      0.14      5285
#       not_LA       0.84      0.69      0.76      3590
#           is       0.59      0.89      0.71      9991
#          set       0.75      0.69      0.71       978
#
#     accuracy                           0.63     19844
#    macro avg       0.66      0.59      0.58     19844
# weighted avg       0.60      0.63      0.57     19844
#
# decision tree:
#               precision    recall  f1-score   support
#
#          get       0.31      0.06      0.11      5285
#       not_LA       0.92      0.87      0.90      3590
#           is       0.62      0.85      0.72      9991
#          set       0.90      0.69      0.78       978
#
#    micro avg       0.67      0.64      0.65     19844
#    macro avg       0.69      0.62      0.63     19844
# weighted avg       0.61      0.64      0.59     19844
#  samples avg       0.64      0.64      0.64     19844
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# knn:
#               precision    recall  f1-score   support
#
#          get       0.43      0.14      0.21      5285
#       not_LA       0.86      0.78      0.82      3590
#           is       0.61      0.83      0.70      9991
#          set       0.92      0.67      0.78       978
#
#    micro avg       0.65      0.63      0.64     19844
#    macro avg       0.71      0.60      0.63     19844
# weighted avg       0.62      0.63      0.59     19844
#  samples avg       0.63      0.63      0.63     19844
# /Users/devang/miniconda3/envs/flask/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# logistic regression:
#               precision    recall  f1-score   support
#
#          get       0.48      0.40      0.43      5285
#       not_LA       0.82      0.72      0.77      3590
#           is       0.61      0.71      0.66      9991
#          set       0.68      0.44      0.54       978
#
#     accuracy                           0.61     19844
#    macro avg       0.65      0.57      0.60     19844
# weighted avg       0.61      0.61      0.61     19844
#
# svm:
#               precision    recall  f1-score   support
#
#          get       0.86      0.01      0.02      5285
#       not_LA       0.89      0.66      0.76      3590
#           is       0.59      0.97      0.73      9991
#          set       0.96      0.55      0.70       978
#
#     accuracy                           0.64     19844
#    macro avg       0.83      0.55      0.55     19844
# weighted avg       0.73      0.64      0.55     19844
